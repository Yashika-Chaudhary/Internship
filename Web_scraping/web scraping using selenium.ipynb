# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r"chromedriver.exe")

# %% [markdown]
# # Question 1

# %%
driver.get("https://www.naukri.com/")

designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Banglore')

search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

job_title = []
job_location = []
company_name = []
experience_required = []

time.sleep(3)
title_tags = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[:10]:
    company = i.text
    company_name.append(company)

experience_tags = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[:10]:
    exp = i.text
    experience_required.append(exp)

print(len(job_title),len(job_location),len(company_name),len(experience_required))

import pandas as pd
df = pd.DataFrame({'Title':job_title, 'Location':job_location, 'Company_name': company_name, 'Experience':experience_required})
df
# Out:
# 10 10 10 10
#                                Title  \
# 0                  Tech Data Analyst
# 1  Celonis & Salesforce Data Analyst
# 2                       Data Analyst
# 3             Knowledge Data Analyst
# 4           Data Analyst (Bangalore)
# 5                       Data Analyst
# 6                       Data Analyst
# 7             Data Analyst - FinTech
# 8     Data Analyst - Python / Pandas
# 9                       Data Analyst
#
#                                             Location  \
# 0  Hybrid - Gurgaon/ Gurugram, Haryana, Bangalore...
# 1                                Bangalore/Bengaluru
# 2                       Hybrid - Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# 7  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# ...

# %% [markdown]
# # Question 2

# %%
driver.get("https://www.naukri.com/")

designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Banglore')

search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

job_title = []
job_location = []
company_name = []

time.sleep(3)
title_tags = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[:10]:
    company = i.text
    company_name.append(company)

print(len(job_title),len(job_location),len(company_name))

import pandas as pd
df = pd.DataFrame({'Title':job_title, 'Location':job_location, 'Company_name': company_name, 'Experience':experience_required})
df
# Out:
# 10 10 10
#                                                Title  \
# 0  Permanent Opportunity - Data Scientist(Snaplog...
# 1                   Analystics & Modeling Specialist
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
# 5                  Deputy Manager - B2C Underwriting
# 6                          Hiring For Data Scientist
# 7                                     Data Scientist
# 8                          Data Scientist - R/Python
# 9                  Data Scientist - Engine Algorithm
#
#                                             Location  \
# 0  Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# ...

# %% [markdown]
# # Question 3

# %%
driver.get("https://www.naukri.com/")

designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()
time.sleep(5)

salary = driver.find_element(By.XPATH,'//*[@id="root"]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/i')
salary.click()
time.sleep(3)
location = driver.find_element(By.XPATH,'//*[@id="root"]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/i')
location.click()


job_title = []
job_location = []
company_name = []

time.sleep(5)
title_tags = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[:10]:
    company = i.text
    company_name.append(company)

print(len(job_title),len(job_location),len(company_name))

import pandas as pd
df = pd.DataFrame({'Title':job_title, 'Location':job_location, 'Company_name': company_name})
df
# Out:
# 10 10 10
#                     Title                                           Location  \
# 0   Junior Data Scientist  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 1   Python and ML Trainer  Hyderabad/Secunderabad, New Delhi, Pune, Gurga...
# 2          Data Scientist              Gurgaon/Gurugram, Bangalore/Bengaluru
# 3          Data Scientist  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 4          Data Scientist                                        Delhi / NCR
# 5                  Intern                                   Gurgaon/Gurugram
# 6          Data Scientist                                              Noida
# 7  Lead Assistant Manager                                   Gurgaon/Gurugram
# 8   Junior Data Scientist    Gurgaon/Gurugram, United States (USA), Bulgaria
# 9  MLOps - Data Scientist                                              Noida
#
#                       Company_name
# 0                         Analytos
# 1                       Thescholar
# ...

# %% [markdown]
# # Question 4

# %%
driver.get("https://www.flipkart.com/")

products = driver.find_element(By.CLASS_NAME,"_3704LK")
products.send_keys('sunglasses')

search = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

brand = []
product_des = []
price = []
offer = []

start = 0
end = 3
for page in range(start,end):
    time.sleep(10)
    brand_tags = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags:
        brand.append(i.text)

    product_tags = driver.find_elements(By.XPATH,'//a[@class="IRpwTa" or @class = "IRpwTa _2-ICcC"]')
    for i in product_tags:
        product_des.append(i.text)

    price_tags = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        price.append(i.text)
        
    offer_tags = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in offer_tags:
        offer.append(i.text)
    if(page==0):
        next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
        next_button.click()
    else:
        next_button= driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')
        next_button[1].click()
    
print(len(brand), len(product_des),len(price),len(offer))

import pandas as pd
df = pd.DataFrame({'Brand':brand, 'Product description': product_des,'Price': price, 'Offer': offer})
df.head(100)
# Out:
# 120 120 120 120
#                     Brand                                Product description  \
# 0                  GANSTA    Gradient, UV Protection Aviator Sunglasses (57)
# 1                 I Flash  UV Protection, Polarized, Gradient Wayfarer, C...
# 2                    SRPM             UV Protection Wayfarer Sunglasses (50)
# 3                    SRPM             UV Protection Wayfarer Sunglasses (50)
# 4               Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# ..                    ...                                                ...
# 95              ROYAL SON                Others Retro Square Sunglasses (52)
# 96          VINCENT CHASE  Polarized, UV Protection Rectangular Sunglasse...
# 97              ROYAL SON   Polarized, UV Protection Aviator Sunglasses (58)
# 98  HRX by Hrithik Roshan                  Polarized Aviator Sunglasses (59)
# 99              ROYAL SON                  Others Over-sized Sunglasses (60)
#
#      Price    Offer
# ...

# %% [markdown]
# # Question 5

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

rating = []
review_summary = []
full_summary = []

start = 0
end = 10
for page in range(start,end):
    time.sleep(10)
    rating_tags = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq" or @class="_3LWZlK _1rdVr6 _1BLPMq"]')
    for i in rating_tags[0:100]:
        rating.append(i.text)
    
    review_tags = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in review_tags[0:100]:
        review_summary.append(i.text)
    
    full_tags = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in full_tags[0:100]:
        full_summary.append(i.text)
    if(page==0):
        next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
        next_button.click()
    else:
        next_button= driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')
        next_button[1].click()

print(len(rating),len(review_summary),len(full_summary))

import pandas as pd
df = pd.DataFrame({'Rating':rating, 'Review': review_summary,'Full Review': full_summary})
df
# Out:
# 100 100 100
#    Rating                Review  \
# 0       5        Simply awesome
# 1       5      Perfect product!
# 2       5   Best in the market!
# 3       5    Highly recommended
# 4       4       Value-for-money
# ..    ...                   ...
# 95      5     Terrific purchase
# 96      4  Good quality product
# 97      5             Wonderful
# 98      5              Terrific
# 99      5   Best in the market!
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   It's my first time to use iOS phone and I am l...
# 4   I'm Really happy with the product\nDelivery wa...
# ..                                                ...
# 95  finally an iPhone with very nice battery backu...
# 96  I'm switching this phone to oppo reno 10x zoom...
# 97  Its good.. a little heavy on my pinky but its ...
# ...

# %% [markdown]
# # Question 6

# %%
driver.get("https://www.flipkart.com/")

products = driver.find_element(By.CLASS_NAME,"_3704LK")
products.send_keys('sneakers')

search = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

brand = []
product_des = []
price = []

start = 0
end = 3
for page in range(start,end):
    time.sleep(10)
    brand_tags = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags[0:100]:
        brand.append(i.text)

    product_tags = driver.find_elements(By.XPATH,'//a[@class="IRpwTa" or @class = "IRpwTa _2-ICcC"]')
    for i in product_tags[0:100]:
        product_des.append(i.text)

    price_tags = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags[0:100]:
        price.append(i.text)

    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()

print(len(brand), len(product_des),len(price))

import pandas as pd
df = pd.DataFrame({'Brand':brand,'Price': price, 'Product Description':product_des})
df.head(100)
# Out:
# 120 120 120
#                   Brand Price  \
# 0                   SFR  ₹299
# 1              RapidBox  ₹699
# 2                  aadi  ₹279
# 3                  aadi  ₹349
# 4   World Wear Footwear  ₹279
# ..                  ...   ...
# 95  World Wear Footwear  ₹419
# 96             RapidBox  ₹549
# 97             RapidBox  ₹549
# 98          kardam&sons  ₹403
# 99                BIRDE  ₹649
#
#                                   Product Description
# 0               Casual Shoes For Men Sneakers For Men
# 1                                    Sneakers For Men
# 2   Synthetic Leather |Lightweight|Comfort|Summer|...
# 3                                    Sneakers For Men
# 4   Latest Exclusive Affordable Collection of Tren...
# ..                                                ...
# 95  Latest Exclusive Affordable Collection of Tren...
# 96                                   Sneakers For Men
# 97                                   Sneakers For Men
# ...

# %% [markdown]
# # Question 7

# %%
driver.get("https://www.amazon.in/")

search = driver.find_element(By.XPATH,'//*[@id="twotabsearchtextbox"]')
search.send_keys('Laptop')

search = driver.find_element(By.XPATH,'//*[@id="nav-search-submit-button"]')
search.click()        

time.sleep(2)
cpu_filter = driver.find_element(By.XPATH,'//*[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span/a/div/label/i')
cpu_filter.click()

title = []
Ratings = []
price = []


title_tags = driver.find_elements(By.XPATH,'//span[@class = "a-size-medium a-color-base a-text-normal"]')
for i in title_tags[:10]:
    title.append(i.text)

rating_tags=driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]/span')
for i in rating_tags:
    Ratings.append(i.get_attribute("aria-label"))
    rating=[]
    for i in range(0,len(Ratings))[0:20]:
        if i%2==0:
            rating.append(Ratings[i])

    
price_tags = driver.find_elements(By.CLASS_NAME, "a-price-whole")
for i in price_tags[:10]:
    price.append(i.text)

print(len(title),len(rating),len(price))

import pandas as pd
df = pd.DataFrame({'Title':title,'Price': price, 'Ratings':rating})
df
# Out:
# 10 10 10
#                                                Title     Price  \
# 0  ASUS TUF Gaming F15 (2023) 90WHr Battery, Inte...  1,15,990
# 1  MSI Thin GF63, Intel 12th Gen. i7-12650H, 40CM...    94,990
# 2  Acer Predator Helios Neo 16 Gaming Laptop 13th...  1,29,990
# 3  Acer Predator Helios Neo 16 Gaming Laptop 13th...  1,49,990
# 4  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...    84,999
# 5  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...    93,990
# 6  HP Victus Gaming Latest 12th Gen Intel Core i7...    90,990
# 7  ASUS TUF Gaming F15 (2022), 15.6"(39.62 cms) F...  1,00,990
# 8  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...    80,990
# 9  Lenovo ThinkPad E14 Intel Core i7 12th Gen 14"...  1,02,490
#
#               Ratings
# 0  5.0 out of 5 stars
# 1  4.3 out of 5 stars
# 2  5.0 out of 5 stars
# 3  4.3 out of 5 stars
# 4  4.0 out of 5 stars
# 5  4.1 out of 5 stars
# 6  4.3 out of 5 stars
# 7  4.4 out of 5 stars
# 8  3.8 out of 5 stars
# 9  3.8 out of 5 stars

# %% [markdown]
# # Question 8

# %%
driver.get("https://www.azquotes.com/")

search = driver.find_element(By.XPATH,'//*[@id="menu"]/div/div[3]/ul/li[5]/a')
search.click()

quote = []
author = []
qtype = []

start = 0
end= 10
for page in range(start,end):
    time.sleep(5)
    quote_tags = driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in quote_tags:
        quote.append(i.text)
        
    author_tags = driver.find_elements(By.CLASS_NAME,"author")
    for i in author_tags:
        author.append(i.text)

    q_tags = driver.find_elements(By.CLASS_NAME,"tags")
    for i in q_tags:
        qtype.append(i.text)
    if(page <9):
        next_button = driver.find_element(By.CLASS_NAME,"next")
        next_button.click()

print(len(quote), len(author), len(qtype))

import pandas as pd
df = pd.DataFrame({'Author':author,'Quotes': quote, 'Quotes type':qtype})
df
# Out:
# 1000 1000 1000
#                  Author                                             Quotes  \
# 0        Michael Porter  The essence of strategy is choosing what not t...
# 1            Golda Meir  One cannot and must not try to erase the past ...
# 2    Theodore Roosevelt  Patriotism means to stand by the country. It d...
# 3        Nelson Mandela  Death is something inevitable. When a man has ...
# 4          Erma Bombeck  You have to love a nation that celebrates its ...
# ..                  ...                                                ...
# 995    Sydney J. Harris  Regret for the things we did can be tempered b...
# 996  Hunter S. Thompson  America... just a nation of two hundred millio...
# 997            Jim Rohn  For every disciplined effort there is a multip...
# 998            Ram Dass  The spiritual journey is individual, highly pe...
# 999            Plutarch  The mind is not a vessel to be filled but a fi...
#
#                                   Quotes type
# ...

# %% [markdown]
# # Question 9

# %%
driver.get("http://www.jagranjosh.com/")

gk = driver.find_element(By.XPATH,'//*[@id="1540978020504"]/div[1]/header/div[3]/ul/li[3]/a')
gk.click()

pm = driver.find_element(By.XPATH,'//*[@id="popluarGK"]/ul/li[2]/a')
pm.click()

pm_name =[]

row = []
col = []
elemt = []

r = driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[2]/table/tbody/tr')
c = driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[2]/table/tbody/tr[1]/th')
i = 0
j = 0
for indx,val in enumerate(c):
    while j < 6:
        i=0
        j+=1
        for idx,val in enumerate(r):    
            while i < 21 :                  
                d=driver.find_elements(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[2]/table/tbody/tr['+str(i)+']/td['+str(j)+']/p')
                for k in d:
                    row.append(k.text) 
                i+=1 
k =[]
n = 57
while n<91:
    t = row[n]+row[n+1]
    n+=2
    k.append(t)
t1 = row[91]
k.append(t1)
t2 = row[92]  
k.append(t2)

import pandas as pd
df = pd.DataFrame({'S.no':row[0:19],'Name': row[19:38], 'Born-Dead': row[38:57], 'Term':k, 'Remark': row[93:112]})
df
# Out:
#    S.no                         Name     Born-Dead  \
# 0    1.            Jawahar Lal Nehru   (1889–1964)
# 1    2.    Gulzarilal Nanda (Acting)   (1898-1998)
# 2    3.          Lal Bahadur Shastri   (1904–1966)
# 3   4.   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4    5.                Indira Gandhi   (1917–1984)
# 5    6.                Morarji Desai   (1896–1995)
# 6    7.                 Charan Singh   (1902–1987)
# 7    8.                Indira Gandhi   (1917–1984)
# 8    9.                 Rajiv Gandhi   (1944–1991)
# 9   10.                  V. P. Singh   (1931–2008)
# 10  11.              Chandra Shekhar   (1927–2007)
# 11  12.          P. V. Narasimha Rao   (1921–2004)
# 12  13.         Atal Bihari Vajpayee  (1924- 2018)
# 13  14.             H. D. Deve Gowda   (born 1933)
# 14  15.           Inder Kumar Gujral   (1919–2012)
# 15  16.         Atal Bihari Vajpayee   (1924-2018)
# 16  17.               Manmohan Singh   (born 1932)
# ...

# %% [markdown]
# # Question 10

# %%
driver.get("https://www.motor1.com/")

features = driver.find_element(By.XPATH,'//*[@id="page_index_index_index"]/div[2]/div/div/div[3]/ul/li[3]/a')
features.click()

p = driver.find_element(By.XPATH,'//*[@id="page_index_articles_browse"]/div[6]/div/div[1]/div[2]/a')
p.click()

a = driver.find_element(By.XPATH,'//*[@id="page_index_articles_browse"]/div[8]/div[1]/div[1]/div/div/div[7]/div/div[1]/h3/a')
a.click()



name = []
price = []

name_tags = driver.find_elements(By.CLASS_NAME,"subheader")
for i in name_tags[0:50]:
    name.append(i.text)

price_tags = driver.find_elements(By.XPATH,"//strong[contains(text(),'$')]")
for i in price_tags[0:50]:
    price.append(i.text)

print(len(price),len(name))

import pandas as pd
df = pd.DataFrame({'Name': name,'Price':price,})
df
# Out:
# 50 50
#                                Name                        Price
# 0                     De Tomaso P72          Price: $1.3 Million
# 1                 Ferrari LaFerrari          Price: $1.4 Million
# 2                     Pagani Huayra          Price: $1.4 Million
# 3                      McLaren Elva          Price: $1.7 Million
# 4                       Czinger 21C          Price: $1.7 Million
# 5                     Ferrari Monza          Price: $1.7 Million
# 6                Gordon Murray T.33          Price: $1.7 Million
# 7                 Koenigsegg Gemera          Price: $1.7 Million
# 8                       Zenvo TSR-S          Price: $1.7 Million
# 9                Hennessey Venom F5          Price: $1.8 Million
# 10                  Bentley Bacalar          Price: $1.9 Million
# 11    Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 12           Bentley Mulliner Batur          Price: $2.0 Million
# ...
